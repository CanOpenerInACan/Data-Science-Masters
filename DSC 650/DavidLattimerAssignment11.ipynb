# %%
import numpy as np
import keras

path = keras.utils.get_file('nietzsche.txt',
                           origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600901

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 20):
    print('Epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('---Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('---temperature:', temperature)
        sys.stdout.write(generated_text)
        
    for i in range(400):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.
            
        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]
        
        generated_text += next_char
        generated_text = generated_text[1:]
        
        sys.stdout.write(next_char)
# Out:
# Epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 371s 2ms/step - loss: 1.9848
# ---Generating with seed: "to mention
# much greater names, but i have them in my mind), "
# ---temperature: 0.2
# to mention
# much greater names, but i have them in my mind), ---temperature: 0.5
# to mention
# much greater names, but i have them in my mind), ---temperature: 1.0
# to mention
# much greater names, but i have them in my mind), ---temperature: 1.2
# to mention
# much greater names, but i have them in my mind), ary hfuevagen evilul uginhiones ider
# persent
# blooura. in a decruapures
# yy whightation.t boditucs.--gredabs noody, iwieh for arting
# dredifened age age: natusoo, fors any from ofucation. wout is pose
# for ewiligy as itself clitus" and itfrates,.-the at c.ine" laty.
# will (otire? refievly d; god?n,
# the tolore.
# doothe,
# still thaidla, opla: seallered in
# the suchor licaltop: he has heett--on the urigdearEpoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 370s 2ms/step - loss: 1.6245
# ---Generating with seed: "not that sincere, austere
# slave-faith by which perhaps a lut"
# ---temperature: 0.2
# not that sincere, austere
# slave-faith by which perhaps a lut---temperature: 0.5
# not that sincere, austere
# slave-faith by which perhaps a lut---temperature: 1.0
# not that sincere, austere
# slave-faith by which perhaps a lut---temperature: 1.2
# not that sincere, austere
# slave-faith by which perhaps a lute thum, which treaks
# rong-there overevare)--rens. in have always, in any only
# is most will's will4? our
# ir, ime! the scriveage the, not palse, newered empear: syives, myrable: it.
#
#  howtoroonht i fnot insy of
# the
# ip stopl,
# the po tear, be wills, or--i reiseby to are, ato
# long was toeperof, neverthesh only ?
#
#
# -
# ermory of the higher most no newtlre they pace of bad; life-bud-in temphless, hne onlEpoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 276s 1ms/step - loss: 1.5317
# ---Generating with seed: " of an imaginary
# sinfulness. go through the separate moral e"
# ---temperature: 0.2
#  of an imaginary
# sinfulness. go through the separate moral e---temperature: 0.5
#  of an imaginary
# sinfulness. go through the separate moral e---temperature: 1.0
#  of an imaginary
# sinfulness. go through the separate moral e---temperature: 1.2
#  of an imaginary
# sinfulness. go through the separate moral enciped sometimes, or germannous ma master impalrvefulesed,
# i! and instancally systequionsh). them facts indender upbes" one, to happen excess of genorate uneod. it
# is grumable,  misthpences; but, if it evil typiege? every rumlened to the littles in satiguwhorual causr to self so falsaided carklymadscho?s, fordmsousness,"--a our lobatherex plebes flootjests
# in mallo "it, ansevolocy, his live to besEpoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 253s 1ms/step - loss: 1.4836
# ---Generating with seed: "answerable for anything, or blamed
# for anything, and owing t"
# ---temperature: 0.2
# answerable for anything, or blamed
# for anything, and owing t---temperature: 0.5
# answerable for anything, or blamed
# for anything, and owing t---temperature: 1.0
# answerable for anything, or blamed
# for anything, and owing t---temperature: 1.2
# answerable for anything, or blamed
# for anything, and owing theses iun: a philosour
# pared untofuted natured todatider
# and nest differ2: theby he phulopisty
# man," of givess and conscursions--ham just this unamleasity rought:"---de tas forcully thists but
# on e
# erchands, as homethich of thos which coul, in the "pronerst
# does abpeninns weli
# expedinging of view liit svect" to on
# in thesed: y, was over badly itle whowly it will ite knowst--his na
# inimany of conceEpoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.4538
# ---Generating with seed: "oil of
# delusion and cupidity, they cannot have their source."
# ---temperature: 0.2
# oil of
# delusion and cupidity, they cannot have their source.---temperature: 0.5
# oil of
# delusion and cupidity, they cannot have their source.---temperature: 1.0
# oil of
# delusion and cupidity, they cannot have their source.---temperature: 1.2
# oil of
# delusion and cupidity, they cannot have their source. "expenauetarize, wood, to really anyimve, thereby believe in all sympanhy ognife simply har, infectester goloning sochilic ardisesshousrafnere! in ficusoun
# fuwhame in
# comean susmicalty, and all youther
# paris and
# denorad faticaty, one who fept many higher sudfo frenchhallyrakelry:  he bad
# to
# imaginal new madiejated
# (mystelled
# himself--it igally if unplato away a
# wayr,
# a will can growing,
# these sufEpoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 252s 1ms/step - loss: 1.4302
# ---Generating with seed: "ve, though certainly the sublimest sort of slave, but
# nothin"
# ---temperature: 0.2
# ve, though certainly the sublimest sort of slave, but
# nothin---temperature: 0.5
# ve, though certainly the sublimest sort of slave, but
# nothin---temperature: 1.0
# ve, though certainly the sublimest sort of slave, but
# nothin---temperature: 1.2
# ve, though certainly the sublimest sort of slave, but
# nothing a magifferer
# nece,sary,
# br lams any sunrestable: ununesstude-gening explasienta
# youthsome
# begins where struvrustrant incoodly-carinys) thing them tymaked, -highcy wat object, : whe our "is sprifts
# ame modert any heavher for act; and does paihan findationi-cle quite winjeranious "plause, in a cornoling refinement of his lith1:. the gold, and-its
# true not belief t"ick. thus--
# ranticaf"2zfor the deEpoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.4127
# ---Generating with seed: "le, who exist for service and
# general utility, and are only "
# ---temperature: 0.2
# le, who exist for service and
# general utility, and are only ---temperature: 0.5
# le, who exist for service and
# general utility, and are only ---temperature: 1.0
# le, who exist for service and
# general utility, and are only ---temperature: 1.2
# le, who exist for service and
# general utility, and are only a danger to their virtur. thought disgundency ofully, ne whichings--they arefully.oqts of capaciory.
# "las seems
# earsfomedness of borre
# civilibter of which all spetie, rapds such gelliness manmidancy of sympath--a casewomish, which concerning
# than for prevailstave--the unsevaration of bher--remotherious times.
#
#
# 0egreach in all most concerningt! they seem to the ask us by human rutudan owicaze rengEpoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 253s 1ms/step - loss: 1.4002
# ---Generating with seed: "iritual will to power, the
# will to "creation of the world," "
# ---temperature: 0.2
# iritual will to power, the
# will to "creation of the world," ---temperature: 0.5
# iritual will to power, the
# will to "creation of the world," ---temperature: 1.0
# iritual will to power, the
# will to "creation of the world," ---temperature: 1.2
# iritual will to power, the
# will to "creation of the world," hor, ha sopaty, what was too mebled free faust, theer
# amomness of lisability. barkings
# of
# "as and coiness on herewical our tuten interphea, was quite less self-opens" most br-ien stiftenceow. to strange of
# gravage out ase when i self reapping both the well among of itpelispals.s, i are not ibstance,
# and thing--which.
#
# otime if therexwe: compoeare, however
# chais, slaver in
# time wick of some reeds aEpoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 253s 1ms/step - loss: 1.3867
# ---Generating with seed: "nd in the end,
# in view of all that women write about "woman,"
# ---temperature: 0.2
# nd in the end,
# in view of all that women write about "woman,---temperature: 0.5
# nd in the end,
# in view of all that women write about "woman,---temperature: 1.0
# nd in the end,
# in view of all that women write about "woman,---temperature: 1.2
# nd in the end,
# in view of all that women write about "woman, a preased which acts as ark: "nuest, renines. the south. to e same
# bare towards! break of plekensity
# as thus is we coarse stands long, for that of thw his met of this mochacial when be feel of the themuamus, which away erough as, if and if
#
# snem ill askept--i short, is a hir, gast as sla"cery,
# oc-dew lare the rouh tent incerovoran, imagious stords, and
# pleherolions, are its life," that but (all sEpoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3753
# ---Generating with seed: "ven the weariness of travel seemed to confine us,
# full of ma"
# ---temperature: 0.2
# ven the weariness of travel seemed to confine us,
# full of ma---temperature: 0.5
# ven the weariness of travel seemed to confine us,
# full of ma---temperature: 1.0
# ven the weariness of travel seemed to confine us,
# full of ma---temperature: 1.2
# ven the weariness of travel seemed to confine us,
# full of man invossus, word and stod sublive sueped cynicus wrongcdus, for exped it".
# natures, origin there 9on east to oppirity, custudiousness, hy art in fimpilssment, hence dopble, doublous morefulseld, i feeks. "whatmilds of the  diffect thy brought. "you realgy capachulh"fini"t, him
# as higher predication,
# by you
# regard to be beadiens the phisiso against "which of human
# man tarkrial mons)," the intla-catEpoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3651
# ---Generating with seed: ",
# worm-like reason, which is not to be slain at once and wit"
# ---temperature: 0.2
# ,
# worm-like reason, which is not to be slain at once and wit---temperature: 0.5
# ,
# worm-like reason, which is not to be slain at once and wit---temperature: 1.0
# ,
# worm-like reason, which is not to be slain at once and wit---temperature: 1.2
# ,
# worm-like reason, which is not to be slain at once and with an adk agmoused, only could "maici(ty,"-what ssjecious make only civilimatism. howeven only to orising--hefaes:
# angr cliigs and the and present here-, sfequesto, ! does priordogy for are long as very postional
# judgmes of those have honour? of the fref
# ersouad brought welce! what his his actri, were thinks and in
#
# yon what they
# betra?ly religile and bombersted, and uncaumcaused from arting
# is
# plaEpoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3561
# ---Generating with seed: "he near, the accessible, in all things possessed of
# color, s"
# ---temperature: 0.2
# he near, the accessible, in all things possessed of
# color, s---temperature: 0.5
# he near, the accessible, in all things possessed of
# color, s---temperature: 1.0
# he near, the accessible, in all things possessed of
# color, s---temperature: 1.2
# he near, the accessible, in all things possessed of
# color, senrive one be bore surhings became
# command,
# faillysle, there is does. howevers bbzard toungest moments in the morably be desirility. love
# to not having to fly charppend
# inspires doneln!
# !
#
# mearch and
# keets should rautes.--for other igzedner
# propose
# antient ungrisc). the cherilievenning head other irreoagistic very falsificipacw" is
# not an observed to envented desirinc
# too) is aes, dill relation
# thEpoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 252s 1ms/step - loss: 1.3486
# ---Generating with seed: " life, are present in superabundance. with one stroke the bo"
# ---temperature: 0.2
#  life, are present in superabundance. with one stroke the bo---temperature: 0.5
#  life, are present in superabundance. with one stroke the bo---temperature: 1.0
#  life, are present in superabundance. with one stroke the bo---temperature: 1.2
#  life, are present in superabundance. with one stroke the bold
# our
# no
# one stall degare knot only (ordends is differently whereves you blook ones. actory? him wimst, whol ingener," se.
# constitut nin-weakfulses, the keer
# the word vortiction--tromy addsed world only only by the variism, highly in this lating punimalativa nerward onteny, everyhousnm. )f one a fellow
# that is to still indrest, every finbmate us. the
# kending enramew, there is if morilodied, of coEpoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3429
# ---Generating with seed: ". if romantic
# fantasy employs the word progress in connectio"
# ---temperature: 0.2
# . if romantic
# fantasy employs the word progress in connectio---temperature: 0.5
# . if romantic
# fantasy employs the word progress in connectio---temperature: 1.0
# . if romantic
# fantasy employs the word progress in connectio---temperature: 1.2
# . if romantic
# fantasy employs the word progress in connection.
#
# imphis hobluul, memilals, a
# rished in shary itself. they
# into others has supermeded
# hentic, alt much is epicuriginance evidence,
# and iher, aver, un
# thess , occasions by his not the hembed itsevel
# lived on potiofy. there
# nelrant aris, again:f of
# vlele
# mat
# physiouotay vase! in
# weradscept in effect, him and against approburable ventivisive it want itness persise generally mythlyeny: and i him to Epoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3382
# ---Generating with seed: "er, be put
# altogether aside. for it is, to all appearances, "
# ---temperature: 0.2
# er, be put
# altogether aside. for it is, to all appearances, ---temperature: 0.5
# er, be put
# altogether aside. for it is, to all appearances, ---temperature: 1.0
# er, be put
# altogether aside. for it is, to all appearances, ---temperature: 1.2
# er, be put
# altogether aside. for it is, to all appearances, roke.
# mun ale boucpa christianity
# crufes; they would refined tacion my truths, posterent,
# in questions!-; we mean, the gris
# C:\Users\David\anaconda3\envs\tensorflow_env\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# i un among and kinds spelled to men, he coulivency to demourt, which much- willdish
# attitute, apabignas up my englishhepes--he ranbit act there
# are twot experience that would ma: bry and belises (bobouragedly "igner congenial
# "sname tallers,", chunch didency of morality," seizEpoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 252s 1ms/step - loss: 1.3323
# ---Generating with seed: "taccato and every rubato, that one should
# divine the sense i"
# ---temperature: 0.2
# taccato and every rubato, that one should
# divine the sense i---temperature: 0.5
# taccato and every rubato, that one should
# divine the sense i---temperature: 1.0
# taccato and every rubato, that one should
# divine the sense i---temperature: 1.2
# taccato and every rubato, that one should
# divine the sense in"fulions-most emphlates mortalizingce.wympatius and a beling of which the brute to youre, not
# such physiologiu mnacral plain, from
# pmo)=-- , "finalness!--of our fundamental visices, omet of
# that the superstition the significance. it is
# good no dytments condredoubled the
# anibed the sound and coverangings when an ebrilleded itself--why rosh
# sensed
# "genuinality" of gratifuter disnoritions.--"discompEpoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3268
# ---Generating with seed: " of adventure,
# our sharpened and fastidious curiosity, our m"
# ---temperature: 0.2
#  of adventure,
# our sharpened and fastidious curiosity, our m---temperature: 0.5
#  of adventure,
# our sharpened and fastidious curiosity, our m---temperature: 1.0
#  of adventure,
# our sharpened and fastidious curiosity, our m---temperature: 1.2
#  of adventure,
# our sharpened and fastidious curiosity, our man profoundlyest, and man of the failurd possession, that
# an wicked and im, wag, and, it someselu heart of his seriated a knowile tentalion) catholicing birit dighoty;
# withswer to system
# of irstingmenhing-od eswile. smiled and florshaable with the croblec)
# proroch by the way man thecr within, himself. consistionful pain, all the truths--as pu
# bad mangad to d! for the more intellect, the sintles; iEpoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 252s 1ms/step - loss: 1.3217
# ---Generating with seed: "ence a
# human being suddenly collapses. in india, the carpent"
# ---temperature: 0.2
# ence a
# human being suddenly collapses. in india, the carpent---temperature: 0.5
# ence a
# human being suddenly collapses. in india, the carpent---temperature: 1.0
# ence a
# human being suddenly collapses. in india, the carpent---temperature: 1.2
# ence a
# human being suddenly collapses. in india, the carpention of as some a "from delicatct," and there is one ethical which now, we coneal some augient tlants to every thinkersy generally as "almosan" strence
# will. a conclustor of fear distancts
# himself will know an in hence of behally seldens
# in order to arisedind nar? in long
# i selvament
# beer hises that
# above the
# fainting the had the--who find distauce.
#
#
# r5ath,
# for the obederedly, sald beman
# knowledgeEpoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3174
# ---Generating with seed: "aculties to this very day revert to these
# primitive processe"
# ---temperature: 0.2
# aculties to this very day revert to these
# primitive processe---temperature: 0.5
# aculties to this very day revert to these
# primitive processe---temperature: 1.0
# aculties to this very day revert to these
# primitive processe---temperature: 1.2
# aculties to this very day revert to these
# primitive processes and values.
#
# 1eey schopenhauerment: "great, and morism of
# light cries.
#
# ote , i padouventive enk of disemacinately gratitude? in the races or is in unconvertage and
# rually
# become in so, to involusoarure in
# reepol;s.--theto undement godbesses progress as in graduifiettw! botalove virbleful in the experisugharis of every grade abgorives cerernce teat omnmellenten--this is not so astimul with fisel
